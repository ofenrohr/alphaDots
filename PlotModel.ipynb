# %%
import sys

import numpy as np
import tensorflow as tf
from tensorflow.python import debug as tf_debug

from keras.callbacks import *
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.initializers import *
from keras.utils.np_utils import to_categorical
from keras.utils import plot_model
import keras.backend as K
from keras.regularizers import l2
from keras.engine.topology import Layer
from keras.utils import plot_model
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

from PIL import Image
from matplotlib.pyplot import imshow
# %matplotlib inline
import random
import gc

from modelServer.models.LineFilterLayer import LineFilterLayer
from modelServer.models.ValueLayer import ValueLayer
# Out:
# Using TensorFlow backend.

# %%
def loadModel(modelPath, width, height):
    # LineFilterLayer has to be set before loading the model
    LineFilterLayer.imgWidth = width
    LineFilterLayer.imgHeight = height
    # ValueLayer has to be set before loading the model
    ValueLayer.imgWidth = width
    ValueLayer.imgHeight = height

    model = load_model(modelPath,
                       custom_objects={'LineFilterLayer':LineFilterLayer,
                       'ValueLayer':ValueLayer})
    return model

# %%
modelPath = 'modelServer/models/alphaZero/model/alphaZeroV1.h5'
model = loadModel(modelPath, 13, 11)
plot_model(model, show_shapes=True, to_file='AlphaZeroV1_architecture.png')
SVG(model_to_dot(model).create(prog='dot', format='svg'))
# Out:
# LineFilterLayer with image size 13 x 11

# %%
modelPath = 'modelServer/models/alphaZero/model/alphaZeroV6.h5'
model = loadModel(modelPath, 13, 11)
plot_model(model, show_shapes=True, to_file='AlphaZeroV6_architecture.png')
SVG(model_to_dot(model).create(prog='dot', format='svg'))
# Out:
# LineFilterLayer with image size 13 x 11

# %%
modelPath = 'modelServer/models/alphaZero/model/alphaZeroV7.h5'
model = loadModel(modelPath, 13, 11)
plot_model(model, show_shapes=True, to_file='AlphaZeroV7_architecture.png')
SVG(model_to_dot(model).create(prog='dot', format='svg'))
# Out:
# LineFilterLayer with image size 13 x 11
# ValueLayer with image size 13 x 11

# %%
modelPath = 'modelServer/models/firstTry/model/model-firstTry.h5'
model = loadModel(modelPath, 13, 11)
plot_model(model, show_shapes=True, to_file='FirstTry_architecture.png')
SVG(model_to_dot(model).create(prog='dot', format='svg'))
